# %%
# !git clone https://huggingface.co/spaces/openai/whisper
# Out:
# Cloning into 'whisper'...
# remote: Enumerating objects: 86, done.
# remote: Total 86 (delta 0), reused 0 (delta 0), pack-reused 86
# Unpacking objects: 100% (86/86), 15.41 KiB | 105.00 KiB/s, done.
# /Users/jozer/Documents/GitHub/chatgptapi_playground/whisper
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 45.3 MB/s eta 0:00:00a 0:00:01
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp310-cp310-macosx_12_0_arm64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 55.4 MB/s eta 0:00:00a 0:00:01
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 1)) (2.28.2)
# Collecting regex!=2019.12.17
#   Using cached regex-2022.10.31-cp310-cp310-macosx_11_0_arm64.whl (287 kB)
# Collecting filelock
#   Using cached filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 1)) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 1)) (23.0)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp310-cp310-macosx_11_0_arm64.whl (173 kB)
# Collecting typing-extensions>=3.7.4.3
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 1)) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 1)) (3.0.1)
# Installing collected packages: tokenizers, typing-extensions, regex, pyyaml, filelock, huggingface-hub, transformers
# Successfully installed filelock-3.9.0 huggingface-hub-0.13.0 pyyaml-6.0 regex-2022.10.31 tokenizers-0.13.2 transformers-4.26.1 typing-extensions-4.5.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting gradio
#   Downloading gradio-3.20.1-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 20.3 MB/s eta 0:00:0000:0100:01
# Collecting altair>=4.2.0
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 34.9 MB/s eta 0:00:00
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (6.0)
# Collecting uvicorn
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (1.5.3)
# Collecting orjson
#   Downloading orjson-3.8.7-cp310-cp310-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl (489 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.3/489.3 kB 31.6 MB/s eta 0:00:00
# Collecting fsspec
#   Downloading fsspec-2023.3.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 14.3 MB/s eta 0:00:00
# Collecting pycryptodome
#   Downloading pycryptodome-3.17-cp35-abi3-macosx_10_9_universal2.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 50.8 MB/s eta 0:00:0000:01
# Collecting pydantic
#   Downloading pydantic-1.10.5-cp310-cp310-macosx_11_0_arm64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.1 MB/s eta 0:00:00a 0:00:01
# Collecting mdit-py-plugins<=0.3.3
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (2.28.2)
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp310-cp310-macosx_11_0_arm64.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 7.7 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.1 MB/s eta 0:00:00
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting markupsafe
#   Downloading MarkupSafe-2.1.2-cp310-cp310-macosx_10_9_universal2.whl (17 kB)
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.1 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting fastapi
#   Downloading fastapi-0.93.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 6.0 MB/s eta 0:00:00
# Collecting jinja2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: numpy in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (1.24.2)
# Requirement already satisfied: aiohttp in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (3.8.4)
# Collecting pillow
#   Downloading Pillow-9.4.0-cp310-cp310-macosx_11_0_arm64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 55.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (4.5.0)
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp310-cp310-macosx_11_0_arm64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 44.3 MB/s eta 0:00:0000:0100:01
# Collecting markdown-it-py[linkify]>=2.0.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 6.6 MB/s eta 0:00:00
# Collecting toolz
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting entrypoints
#   Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 5.4 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from pandas->gradio) (2022.7.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (22.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (4.0.2)
# Collecting starlette<0.26.0,>=0.25.0
#   Downloading starlette-0.25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.7 MB/s eta 0:00:00
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 4.5 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from httpx->gradio) (2022.12.7)
# Collecting sniffio
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from matplotlib->gradio) (23.0)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp310-cp310-macosx_11_0_arm64.whl (63 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp310-cp310-macosx_11_0_arm64.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 15.0 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.7 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from requests->gradio) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from requests->gradio) (3.4)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00
# Collecting click>=7.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting anyio<5.0,>=3.0
#   Using cached anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp310-cp310-macosx_10_9_universal2.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 8.3 MB/s eta 0:00:00
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: six>=1.5 in /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Installing collected packages: rfc3986, pydub, ffmpy, websockets, uc-micro-py, toolz, sniffio, python-multipart, pyrsistent, pyparsing, pydantic, pycryptodome, pillow, orjson, mdurl, markupsafe, kiwisolver, h11, fsspec, fonttools, entrypoints, cycler, contourpy, click, aiofiles, uvicorn, matplotlib, markdown-it-py, linkify-it-py, jsonschema, jinja2, anyio, starlette, mdit-py-plugins, httpcore, altair, httpx, fastapi, gradio
#   DEPRECATION: ffmpy is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for ffmpy ... done
# Successfully installed aiofiles-23.1.0 altair-4.2.2 anyio-3.6.2 click-8.1.3 contourpy-1.0.7 cycler-0.11.0 entrypoints-0.4 fastapi-0.93.0 ffmpy-0.3.0 fonttools-4.39.0 fsspec-2023.3.0 gradio-3.20.1 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 jinja2-3.1.2 jsonschema-4.17.3 kiwisolver-1.4.4 linkify-it-py-2.0.0 markdown-it-py-2.2.0 markupsafe-2.1.2 matplotlib-3.7.1 mdit-py-plugins-0.3.3 mdurl-0.1.2 orjson-3.8.7 pillow-9.4.0 pycryptodome-3.17 pydantic-1.10.5 pydub-0.25.1 pyparsing-3.0.9 pyrsistent-0.19.3 python-multipart-0.0.6 rfc3986-1.5.0 sniffio-1.3.0 starlette-0.25.0 toolz-0.12.0 uc-micro-py-1.0.1 uvicorn-0.20.0 websockets-10.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd whisper
# Out:
# [Errno 2] No such file or directory: 'whisper'
# /Users/jozer/Documents/GitHub/chatgptapi_playground/whisper

# %%
#Install in terminal
# %pip install -r requirements.txt
# %pip install gradio
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gradio in ./env_chatgptapi_playground/lib/python3.10/site-packages (3.20.1)
# Requirement already satisfied: jinja2 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: altair>=4.2.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (4.2.2)
# Requirement already satisfied: pyyaml in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (6.0)
# Requirement already satisfied: ffmpy in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: markupsafe in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (2.1.2)
# Requirement already satisfied: pydantic in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (1.10.5)
# Requirement already satisfied: numpy in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (1.23.5)
# Requirement already satisfied: pandas in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pydub in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pycryptodome in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (3.17)
# Requirement already satisfied: matplotlib in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: pillow in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (9.4.0)
# Requirement already satisfied: requests in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (2.28.2)
# Requirement already satisfied: aiofiles in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: uvicorn in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (0.20.0)
# Requirement already satisfied: aiohttp in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: orjson in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (3.8.7)
# Requirement already satisfied: typing-extensions in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (4.5.0)
# Requirement already satisfied: fsspec in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (2023.3.0)
# Requirement already satisfied: fastapi in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (0.93.0)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: httpx in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (0.23.3)
# Requirement already satisfied: websockets>=10.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from gradio) (10.4)
# Requirement already satisfied: entrypoints in ./env_chatgptapi_playground/lib/python3.10/site-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in ./env_chatgptapi_playground/lib/python3.10/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from pandas->gradio) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (3.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: starlette<0.26.0,>=0.25.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from fastapi->gradio) (0.25.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: certifi in ./env_chatgptapi_playground/lib/python3.10/site-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: sniffio in ./env_chatgptapi_playground/lib/python3.10/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from matplotlib->gradio) (23.0)
# Requirement already satisfied: cycler>=0.10 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from matplotlib->gradio) (4.39.0)
# Requirement already satisfied: idna<4,>=2.5 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from requests->gradio) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from requests->gradio) (1.26.14)
# Requirement already satisfied: h11>=0.8 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from uvicorn->gradio) (0.14.0)
# Requirement already satisfied: click>=7.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from uvicorn->gradio) (8.1.3)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (3.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in ./env_chatgptapi_playground/lib/python3.10/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.1)
# Requirement already satisfied: six>=1.5 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.system("pip install git+https://github.com/openai/whisper.git")
import gradio as gr
import whisper
import sys
#sys.path.append("/Users/jozer/Documents/GitHub/chatgptapi_playground/whisper/share_btn.py/")
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /private/var/folders/jb/d9kkhgds2_sgd7vj5m5kpw5m0000gq/T/pip-req-build-gke4ab8u
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /private/var/folders/jb/d9kkhgds2_sgd7vj5m5kpw5m0000gq/T/pip-req-build-gke4ab8u
#   Resolved https://github.com/openai/whisper.git to commit ad3250a846fe7553a25064a2dc593e492dadf040
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: more-itertools in ./env_chatgptapi_playground/lib/python3.10/site-packages (from openai-whisper==20230308) (9.1.0)
# Requirement already satisfied: numba in ./env_chatgptapi_playground/lib/python3.10/site-packages (from openai-whisper==20230308) (0.56.4)
# Requirement already satisfied: torch in ./env_chatgptapi_playground/lib/python3.10/site-packages (from openai-whisper==20230308) (1.13.1)
# Requirement already satisfied: numpy in ./env_chatgptapi_playground/lib/python3.10/site-packages (from openai-whisper==20230308) (1.23.5)
# Requirement already satisfied: tqdm in ./env_chatgptapi_playground/lib/python3.10/site-packages (from openai-whisper==20230308) (4.65.0)
# Requirement already satisfied: ffmpeg-python==0.2.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from openai-whisper==20230308) (0.2.0)
# Requirement already satisfied: transformers>=4.19.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from openai-whisper==20230308) (4.26.1)
# Requirement already satisfied: future in ./env_chatgptapi_playground/lib/python3.10/site-packages (from ffmpeg-python==0.2.0->openai-whisper==20230308) (0.18.3)
# Requirement already satisfied: filelock in ./env_chatgptapi_playground/lib/python3.10/site-packages (from transformers>=4.19.0->openai-whisper==20230308) (3.9.0)
# Requirement already satisfied: packaging>=20.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from transformers>=4.19.0->openai-whisper==20230308) (23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from transformers>=4.19.0->openai-whisper==20230308) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from transformers>=4.19.0->openai-whisper==20230308) (0.13.0)
# Requirement already satisfied: requests in ./env_chatgptapi_playground/lib/python3.10/site-packages (from transformers>=4.19.0->openai-whisper==20230308) (2.28.2)
# Requirement already satisfied: regex!=2019.12.17 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from transformers>=4.19.0->openai-whisper==20230308) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from transformers>=4.19.0->openai-whisper==20230308) (6.0)
# Requirement already satisfied: setuptools in ./env_chatgptapi_playground/lib/python3.10/site-packages (from numba->openai-whisper==20230308) (58.1.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from numba->openai-whisper==20230308) (0.39.1)
# Requirement already satisfied: typing-extensions in ./env_chatgptapi_playground/lib/python3.10/site-packages (from torch->openai-whisper==20230308) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from requests->transformers>=4.19.0->openai-whisper==20230308) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from requests->transformers>=4.19.0->openai-whisper==20230308) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from requests->transformers>=4.19.0->openai-whisper==20230308) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./env_chatgptapi_playground/lib/python3.10/site-packages (from requests->transformers>=4.19.0->openai-whisper==20230308) (1.26.14)

# %%
# !ln -s /Users/jozer/Documents/GitHub/chatgptapi_playground/whisper/share_btn.py share_btn.py

import share_btn

from share_btn import *
from share_btn import community_icon_html, loading_icon_html, share_js

# %%
model = whisper.load_model("small")
  
def inference(audio):
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)
    
    mel = whisper.log_mel_spectrogram(audio).to(model.device)
    
    _, probs = model.detect_language(mel)
    
    options = whisper.DecodingOptions(fp16 = False)
    result = whisper.decode(model, mel, options)
    
    print(result.text)
    return result.text, gr.update(visible=True), gr.update(visible=True), gr.update(visible=True)




css = """
        .gradio-container {
            font-family: 'IBM Plex Sans', sans-serif;
        }
        .gr-button {
            color: white;
            border-color: black;
            background: black;
        }
        input[type='range'] {
            accent-color: black;
        }
        .dark input[type='range'] {
            accent-color: #dfdfdf;
        }
        .container {
            max-width: 730px;
            margin: auto;
            padding-top: 1.5rem;
        }
     
        .details:hover {
            text-decoration: underline;
        }
        .gr-button {
            white-space: nowrap;
        }
        .gr-button:focus {
            border-color: rgb(147 197 253 / var(--tw-border-opacity));
            outline: none;
            box-shadow: var(--tw-ring-offset-shadow), var(--tw-ring-shadow), var(--tw-shadow, 0 0 #0000);
            --tw-border-opacity: 1;
            --tw-ring-offset-shadow: var(--tw-ring-inset) 0 0 0 var(--tw-ring-offset-width) var(--tw-ring-offset-color);
            --tw-ring-shadow: var(--tw-ring-inset) 0 0 0 calc(3px var(--tw-ring-offset-width)) var(--tw-ring-color);
            --tw-ring-color: rgb(191 219 254 / var(--tw-ring-opacity));
            --tw-ring-opacity: .5;
        }
        .footer {
            margin-bottom: 45px;
            margin-top: 35px;
            text-align: center;
            border-bottom: 1px solid #e5e5e5;
        }
        .footer>p {
            font-size: .8rem;
            display: inline-block;
            padding: 0 10px;
            transform: translateY(10px);
            background: white;
        }
        .dark .footer {
            border-color: #303030;
        }
        .dark .footer>p {
            background: #0b0f19;
        }
        .prompt h4{
            margin: 1.25em 0 .25em 0;
            font-weight: bold;
            font-size: 115%;
        }
        .animate-spin {
            animation: spin 1s linear infinite;
        }
        @keyframes spin {
            from {
                transform: rotate(0deg);
            }
            to {
                transform: rotate(360deg);
            }
        }
        #share-btn-container {
            display: flex; margin-top: 1.5rem !important; padding-left: 0.5rem !important; padding-right: 0.5rem !important; background-color: #000000; justify-content: center; align-items: center; border-radius: 9999px !important; width: 13rem;
        }
        #share-btn {
            all: initial; color: #ffffff;font-weight: 600; cursor:pointer; font-family: 'IBM Plex Sans', sans-serif; margin-left: 0.5rem !important; padding-top: 0.25rem !important; padding-bottom: 0.25rem !important;
        }
        #share-btn * {
            all: unset;
        }
"""

block = gr.Blocks(css=css)



with block:
    gr.HTML(
        """
            <div style="text-align: center; max-width: 650px; margin: 0 auto;">
              <div
                style="
                  display: inline-flex;
                  align-items: center;
                  gap: 0.8rem;
                  font-size: 1.75rem;
                "
              >
                <svg
                  width="0.65em"
                  height="0.65em"
                  viewBox="0 0 115 115"
                  fill="none"
                  xmlns="http://www.w3.org/2000/svg"
                >
                  <rect width="23" height="23" fill="white"></rect>
                  <rect y="69" width="23" height="23" fill="white"></rect>
                  <rect x="23" width="23" height="23" fill="#AEAEAE"></rect>
                  <rect x="23" y="69" width="23" height="23" fill="#AEAEAE"></rect>
                  <rect x="46" width="23" height="23" fill="white"></rect>
                  <rect x="46" y="69" width="23" height="23" fill="white"></rect>
                  <rect x="69" width="23" height="23" fill="black"></rect>
                  <rect x="69" y="69" width="23" height="23" fill="black"></rect>
                  <rect x="92" width="23" height="23" fill="#D9D9D9"></rect>
                  <rect x="92" y="69" width="23" height="23" fill="#AEAEAE"></rect>
                  <rect x="115" y="46" width="23" height="23" fill="white"></rect>
                  <rect x="115" y="115" width="23" height="23" fill="white"></rect>
                  <rect x="115" y="69" width="23" height="23" fill="#D9D9D9"></rect>
                  <rect x="92" y="46" width="23" height="23" fill="#AEAEAE"></rect>
                  <rect x="92" y="115" width="23" height="23" fill="#AEAEAE"></rect>
                  <rect x="92" y="69" width="23" height="23" fill="white"></rect>
                  <rect x="69" y="46" width="23" height="23" fill="white"></rect>
                  <rect x="69" y="115" width="23" height="23" fill="white"></rect>
                  <rect x="69" y="69" width="23" height="23" fill="#D9D9D9"></rect>
                  <rect x="46" y="46" width="23" height="23" fill="black"></rect>
                  <rect x="46" y="115" width="23" height="23" fill="black"></rect>
                  <rect x="46" y="69" width="23" height="23" fill="black"></rect>
                  <rect x="23" y="46" width="23" height="23" fill="#D9D9D9"></rect>
                  <rect x="23" y="115" width="23" height="23" fill="#AEAEAE"></rect>
                  <rect x="23" y="69" width="23" height="23" fill="black"></rect>
                </svg>
                <h1 style="font-weight: 900; margin-bottom: 7px;">
                  Whisper
                </h1>
              </div>
              <p style="margin-bottom: 10px; font-size: 94%">
                Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification. This demo cuts audio after around 30 secs.
              </p>
            </div>
        """
    )
    with gr.Group():
        with gr.Box():
            with gr.Row().style(mobile_collapse=False, equal_height=True):
                audio = gr.Audio(
                    label="Input Audio",
                    show_label=False,
                    source="microphone",
                    type="filepath"
                )

                btn = gr.Button("Transcribe")
        text = gr.Textbox(show_label=False, elem_id="result-textarea")
        with gr.Group(elem_id="share-btn-container"):
            community_icon = gr.HTML(community_icon_html, visible=False)
            loading_icon = gr.HTML(loading_icon_html, visible=False)
            share_button = gr.Button("Share to community", elem_id="share-btn", visible=False)
        


        
        btn.click(inference, inputs=[audio], outputs=[text, community_icon, loading_icon, share_button])
        share_button.click(None, [], [], _js=share_js)
 
        gr.HTML('''
        <div class="footer">
                    <p>Model by <a href="https://github.com/openai/whisper" style="text-decoration: underline;" target="_blank">OpenAI</a> - Gradio Demo by 🤗 Hugging Face
                    </p>
        </div>
        ''')

#block.launch()
block.launch(share=True)
# Out:
# /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/gradio/layouts.py:75: UserWarning: mobile_collapse is no longer supported.
#   warnings.warn("mobile_collapse is no longer supported.")
# Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/pydub/utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# Traceback (most recent call last):
#   File "/Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/gradio/processing_utils.py", line 200, in audio_from_file
#     audio = AudioSegment.from_file(filename)
#   File "/Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/pydub/audio_segment.py", line 728, in from_file
#     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#   File "/Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/pydub/utils.py", line 274, in mediainfo_json
#     res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py", line 966, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py", line 1842, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ffprobe'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/gradio/routes.py", line 384, in run_predict
#     output = await app.get_blocks().process_api(
#   File "/Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/gradio/blocks.py", line 1030, in process_api
#     inputs = self.preprocess_data(fn_index, inputs, state)
#   File "/Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/gradio/blocks.py", line 922, in preprocess_data
#     processed_input.append(block.preprocess(inputs[i]))
#   File "/Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/gradio/components.py", line 2087, in preprocess
#     sample_rate, data = processing_utils.audio_from_file(
#   File "/Users/jozer/Documents/GitHub/chatgptapi_playground/env_chatgptapi_playground/lib/python3.10/site-packages/gradio/processing_utils.py", line 210, in audio_from_file
#     raise RuntimeError(msg) from e
# RuntimeError: Cannot load audio from file: `ffprobe` not found. Please install `ffmpeg` in your system to use non-WAV audio file formats and make sure `ffprobe` is in your PATH.
